# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#imprting dataset
df = pd.read_csv("customer_churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.drop('customerID', axis = 'columns', inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.MonthlyCharges.values
# Out:
# array([ 29.85,  56.95,  53.85, ...,  29.6 ,  74.4 , 105.65])

# %%
pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 488   Female              0     Yes  ...          52.55                  No
# 753     Male              0      No  ...          20.25                  No
# 936   Female              0     Yes  ...          80.85                  No
# 1082    Male              0     Yes  ...          25.75                  No
# 1340  Female              0     Yes  ...          56.05                  No
# 3331    Male              0     Yes  ...          19.85                  No
# 3826    Male              0     Yes  ...          25.35                  No
# 4380  Female              0     Yes  ...          20.00                  No
# 5218    Male              0     Yes  ...          19.70                  No
# 6670  Female              0     Yes  ...          73.35                  No
# 6754    Male              0      No  ...          61.90                  No
#
# [11 rows x 20 columns]

# %%
df.iloc[488]
# Out:
# gender                                 Female
# SeniorCitizen                               0
# Partner                                   Yes
# Dependents                                Yes
# tenure                                      0
# PhoneService                               No
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                            Yes
# OnlineBackup                               No
# DeviceProtection                          Yes
# TechSupport                               Yes
# StreamingTV                               Yes
# StreamingMovies                            No
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# Name: 488, dtype: object

# %%
df.iloc[488]['TotalCharges']
# Out:
# ' '

# %%
#lets drop all this code using boolean condition

df1 = df[df.TotalCharges!= ' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# <ipython-input-15-b67e0c3d31a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df1[df1.Churn == 'No']
# Out:
#       gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 0     Female              0     Yes  ...          29.85         29.85    No
# 1       Male              0      No  ...          56.95       1889.50    No
# 3       Male              0      No  ...          42.30       1840.75    No
# 6       Male              0      No  ...          89.10       1949.40    No
# 7     Female              0      No  ...          29.75        301.90    No
# ...      ...            ...     ...  ...            ...           ...   ...
# 7037  Female              0      No  ...          21.15       1419.40    No
# 7038    Male              0     Yes  ...          84.80       1990.50    No
# 7039  Female              0     Yes  ...         103.20       7362.90    No
# 7040  Female              0     Yes  ...          29.60        346.45    No
# 7042    Male              0      No  ...         105.65       6844.50    No
#
# [5163 rows x 20 columns]

# %%
df1[df1.Churn == 'No'].tenure
# Out:
# 0        1
# 1       34
# 3       45
# 6       22
# 7       10
#         ..
# 7037    72
# 7038    24
# 7039    72
# 7040    11
# 7042    66
# Name: tenure, Length: 5163, dtype: int64

# %%
#Visualizating the Churn with respeset to tensure
tenure_churn_no = df1[df1.Churn == 'No'].tenure
tenure_churn_yes = df1[df1.Churn == 'Yes'].tenure


plt.xlabel('tenure')
plt.ylabel('Number Of Customers')
plt.title('customer Churn Prediction Visualiztion')
plt.hist([tenure_churn_yes, tenure_churn_no], color=['green', 'red'], label = ['Churn = Yes', 'Churn = No'])
plt.legend()

# %%
df1[df1.Churn=='No'].MonthlyCharges
# Out:
# 0        29.85
# 1        56.95
# 3        42.30
# 6        89.10
# 7        29.75
#          ...
# 7037     21.15
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7042    105.65
# Name: MonthlyCharges, Length: 5163, dtype: float64

# %%
#Visualizating the Churn with respeset to Monthly charges

mc_churn_no = df1[df1.Churn == 'No'].MonthlyCharges
mc_churn_yes = df1[df1.Churn == 'Yes'].MonthlyCharges

plt.xlabel('Monthly Charges')
plt.ylabel('Number of Customer')
plt.title("Customer Churn Prediction visualization")

plt.hist([mc_churn_yes, mc_churn_no], rwidth = 0.95, color=['green', 'red'], label = ['Churn=Yes', 'Churn=No'])
plt.legend()

# %%
#printingunique values of all catgorical values in each column
def print_unique_col_values(df):
 for column in df:
   if df[column].dtypes=='object':
    print(f' {column} : {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
#  gender : ['Female' 'Male']
#  Partner : ['Yes' 'No']
#  Dependents : ['No' 'Yes']
#  PhoneService : ['No' 'Yes']
#  MultipleLines : ['No phone service' 'No' 'Yes']
#  InternetService : ['DSL' 'Fiber optic' 'No']
#  OnlineSecurity : ['No' 'Yes' 'No internet service']
#  OnlineBackup : ['Yes' 'No' 'No internet service']
#  DeviceProtection : ['No' 'Yes' 'No internet service']
#  TechSupport : ['No' 'Yes' 'No internet service']
#  StreamingTV : ['No' 'Yes' 'No internet service']
#  StreamingMovies : ['No' 'Yes' 'No internet service']
#  Contract : ['Month-to-month' 'One year' 'Two year']
#  PaperlessBilling : ['Yes' 'No']
#  PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#  Churn : ['No' 'Yes']

# %%
df1.replace('No internet service', 'No', inplace = True)
df1.replace('No phone service', 'No', inplace =True)
# Out:
# <ipython-input-24-23e1ae7e87c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace = True)
# <ipython-input-24-23e1ae7e87c4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service', 'No', inplace =True)

# %%
print_unique_col_values(df1)
# Out:
#  gender : ['Female' 'Male']
#  Partner : ['Yes' 'No']
#  Dependents : ['No' 'Yes']
#  PhoneService : ['No' 'Yes']
#  MultipleLines : ['No' 'Yes']
#  InternetService : ['DSL' 'Fiber optic' 'No']
#  OnlineSecurity : ['No' 'Yes']
#  OnlineBackup : ['Yes' 'No']
#  DeviceProtection : ['No' 'Yes']
#  TechSupport : ['No' 'Yes']
#  StreamingTV : ['No' 'Yes']
#  StreamingMovies : ['No' 'Yes']
#  Contract : ['Month-to-month' 'One year' 'Two year']
#  PaperlessBilling : ['Yes' 'No']
#  PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#  Churn : ['No' 'Yes']

# %%
#converting Yes & no to 0 & 1

yes_no_columns = ['Partner', 'Dependents', 'PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport',
                  'StreamingTV','StreamingMovies', 'PaperlessBilling', 'Churn']

for col in yes_no_columns:
  df1[col].replace({'Yes': 1, 'No':0}, inplace =True)
# Out:
# <ipython-input-26-0bec6c5f278d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes': 1, 'No':0}, inplace =True)

# %%
for col in df1:
  print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
#converting gender to 0&1
df1['gender'].replace({'Female':1, 'Male':0}, inplace = True)
# Out:
# <ipython-input-28-918b391f7e55>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1, 'Male':0}, inplace = True)

# %%
df1['gender'].unique()
# Out:
# array([1, 0])

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract', 'PaymentMethod'], dtype=int)
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  ...  PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 1747       1              0  ...                               0                           0
# 475        0              0  ...                               1                           0
# 4480       1              0  ...                               0                           1
# 5193       1              0  ...                               0                           0
# 5227       0              0  ...                               1                           0
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          int64
# InternetService_Fiber optic                  int64
# InternetService_No                           int64
# Contract_Month-to-month                      int64
# Contract_One year                            int64
# Contract_Two year                            int64
# PaymentMethod_Bank transfer (automatic)      int64
# PaymentMethod_Credit card (automatic)        int64
# PaymentMethod_Electronic check               int64
# PaymentMethod_Mailed check                   int64
# dtype: object

# %%
#scaling the columns which are not in the format of 0&1

cols_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  ...  PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 1592       1              0  ...                               0                           0
# 3128       0              0  ...                               0                           0
# 6089       1              1  ...                               1                           0
# 1686       1              0  ...                               1                           0
# 4251       1              0  ...                               0                           1
#
# [5 rows x 27 columns]

# %%
for col in df2:
  print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
#splitting data for train and test
X = df2.drop('Churn', axis='columns')
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  ...  PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 5664       1              1  ...                               0                           0
# 101        1              0  ...                               1                           0
# 2621       0              0  ...                               0                           0
# 392        1              1  ...                               1                           0
# 1327       0              0  ...                               0                           0
# 3607       1              0  ...                               0                           1
# 2773       0              0  ...                               1                           0
# 1936       1              0  ...                               0                           0
# 5387       0              0  ...                               1                           0
# 4331       0              0  ...                               0                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %%
#creating model
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(26,), activation = 'relu'),
    keras.layers.Dense(15, activation = 'relu'),
    keras.layers.Dense(1, activation = 'sigmoid'),
])

model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])
model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 2s 2ms/step - loss: 0.4948 - accuracy: 0.7554
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.7972
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4196 - accuracy: 0.8028
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4157 - accuracy: 0.8066
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4133 - accuracy: 0.8068
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4126 - accuracy: 0.8036
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8059
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4088 - accuracy: 0.8059
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4079 - accuracy: 0.8078
# Epoch 10/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4060 - accuracy: 0.8078
# Epoch 11/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4056 - accuracy: 0.8069
# Epoch 12/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4053 - accuracy: 0.8080
# Epoch 13/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4032 - accuracy: 0.8117
# Epoch 14/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4031 - accuracy: 0.8116
# Epoch 15/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4024 - accuracy: 0.8101
# Epoch 16/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4012 - accuracy: 0.8110
# Epoch 17/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4009 - accuracy: 0.8121
# Epoch 18/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3994 - accuracy: 0.8142
# Epoch 19/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8112
# Epoch 20/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8148
# Epoch 21/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3975 - accuracy: 0.8137
# Epoch 22/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3973 - accuracy: 0.8108
# Epoch 23/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3963 - accuracy: 0.8116
# Epoch 24/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3954 - accuracy: 0.8148
# Epoch 25/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3954 - accuracy: 0.8126
# Epoch 26/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3943 - accuracy: 0.8151
# Epoch 27/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3946 - accuracy: 0.8151
# Epoch 28/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8151
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3919 - accuracy: 0.8144
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3913 - accuracy: 0.8155
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3907 - accuracy: 0.8164
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8169
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8126
# Epoch 34/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3893 - accuracy: 0.8158
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8151
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3877 - accuracy: 0.8153
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3875 - accuracy: 0.8174
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3871 - accuracy: 0.8180
# Epoch 39/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3867 - accuracy: 0.8181
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8183
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3851 - accuracy: 0.8196
# Epoch 42/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8176
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3846 - accuracy: 0.8171
# Epoch 44/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3830 - accuracy: 0.8188
# Epoch 45/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8204
# Epoch 46/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3823 - accuracy: 0.8192
# Epoch 47/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.8210
# Epoch 48/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3811 - accuracy: 0.8180
# Epoch 49/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8222
# Epoch 50/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3807 - accuracy: 0.8196
# Epoch 51/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3793 - accuracy: 0.8183
# Epoch 52/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3799 - accuracy: 0.8222
# Epoch 53/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3785 - accuracy: 0.8215
# Epoch 54/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3785 - accuracy: 0.8213
# Epoch 55/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3774 - accuracy: 0.8212
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3765 - accuracy: 0.8210
# Epoch 57/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8220
# Epoch 58/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3756 - accuracy: 0.8236
# Epoch 59/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8210
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3756 - accuracy: 0.8217
# Epoch 61/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3747 - accuracy: 0.8245
# Epoch 62/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3743 - accuracy: 0.8213
# Epoch 63/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.8238
# Epoch 64/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3732 - accuracy: 0.8251
# Epoch 65/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3736 - accuracy: 0.8229
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3730 - accuracy: 0.8228
# Epoch 67/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.8220
# Epoch 68/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8228
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8222
# Epoch 70/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.8240
# Epoch 71/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.8231
# Epoch 72/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3707 - accuracy: 0.8206
# Epoch 73/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3699 - accuracy: 0.8261
# Epoch 74/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3703 - accuracy: 0.8229
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3696 - accuracy: 0.8268
# Epoch 76/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3695 - accuracy: 0.8219
# Epoch 77/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3681 - accuracy: 0.8220
# Epoch 78/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3679 - accuracy: 0.8244
# Epoch 79/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3680 - accuracy: 0.8249
# Epoch 80/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3667 - accuracy: 0.8254
# Epoch 81/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3662 - accuracy: 0.8236
# Epoch 82/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3679 - accuracy: 0.8258
# Epoch 83/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3658 - accuracy: 0.8236
# Epoch 84/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3648 - accuracy: 0.8270
# Epoch 85/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3642 - accuracy: 0.8245
# Epoch 86/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8261
# Epoch 87/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3642 - accuracy: 0.8235
# Epoch 88/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8238
# Epoch 89/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3636 - accuracy: 0.8245
# Epoch 90/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3631 - accuracy: 0.8256
# Epoch 91/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8284
# Epoch 92/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3613 - accuracy: 0.8267
# Epoch 93/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3624 - accuracy: 0.8268
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3611 - accuracy: 0.8267
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3613 - accuracy: 0.8245
# Epoch 96/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8247
# Epoch 97/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8276
# Epoch 98/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.8281
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3591 - accuracy: 0.8254
# Epoch 100/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3592 - accuracy: 0.8274

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 1s 4ms/step - loss: 0.4681 - accuracy: 0.7882
# [0.46814611554145813, 0.7882018685340881]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 2ms/step
# array([[0.22778216],
#        [0.4328744 ],
#        [0.01730669],
#        [0.80824065],
#        [0.15569735]], dtype=float32)

# %%
y_test[:5]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# Name: Churn, dtype: int64

# %%
y_pred = []
for element in yp:
  if element > 0.5:
    y_pred.append(1)
  else:
    y_pred.append(0)

# %%
y_pred[:5]
# Out:
# [0, 0, 0, 1, 0]

# %%
#checking classification report
 from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86       999
#            1       0.66      0.55      0.60       408
#
#     accuracy                           0.79      1407
#    macro avg       0.75      0.72      0.73      1407
# weighted avg       0.78      0.79      0.78      1407

# %%
#plotting confusion matrix

import seaborn as sn
cm = tf.math.confusion_matrix(labels = y_test, predictions = y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot = True, fmt = 'd')
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
